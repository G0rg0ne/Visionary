# %%
import pandas as pd

# %%
df = pd.read_csv("../data/04_feature/tickets_train_data.csv")

# %%
df.columns
# Out:
# Index(['origin', 'destination', 'days_before_departure', 'airline', 'price',
#        'stops', 'flight_duration', 'departure_day_of_week',
#        'departure_is_weekend', 'departure_time_hour', 'departure_time_minute',
#        'arrival_time_hour', 'arrival_time_minute', 'origin_country',
#        'destination_country', 'origin_departure_holidays',
#        'destination_departure_holidays'],
#       dtype='object')

# %%
df
# Out:
#       origin destination  days_before_departure                airline  price  \
# 0        CDG         AMS                     12             Air France  117.0
# 1        CDG         ATH                    105  Scandinavian Airlines  113.0
# 2        CDG         ATH                    104                  TAROM  108.0
# 3        CDG         ATH                    104                 Aegean  241.0
# 4        CDG         ATH                    104            SKY express  172.0
# ...      ...         ...                    ...                    ...    ...
# 71505    MAD         CDG                     45                 Iberia   47.0
# 71506    MAD         CDG                     44             Air France  118.0
# 71507    MAD         CDG                     44             Air France  131.0
# 71508    MAD         CDG                     46                 Iberia   47.0
# 71509    MAD         CDG                     44                 Iberia   98.0
#
# ...
